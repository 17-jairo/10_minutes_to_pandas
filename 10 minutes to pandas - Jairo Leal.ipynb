# %% [markdown]
# ### This is a short introduction to Pandas, "10 minutes to Pandas," which is available on pandas.pydata.org. I used a database hosted in Quebec Données called "Historique-consommation-electricite-par-secteur-activite_municipalite".

# %% [raw]
# Jairo Leal

# %%
import numpy as np
import pandas as pd

# %%
s= pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20230101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2023-01-01 -1.043664  0.464047 -0.802140 -0.271679
# 2023-01-02  1.459976  2.230667  1.599419 -1.365192
# 2023-01-03  0.293141  0.265877 -1.408161  0.899458
# 2023-01-04  0.551163 -0.393835  0.177182 -0.469340
# 2023-01-05 -1.245195 -0.102880 -0.125115 -0.844506
# 2023-01-06  0.556338  0.035768 -0.936782 -0.266697

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
consummation_electricite = r'C:\Users\Jairo\OneDrive\Documentos\Data\CodeAcademy_Data_Science\Python\10_minutes_to_pandas\2022-10_Historique-consommation-electricite-par-secteur-activite_municipalite.xlsx'

# %%
ce= pd.read_excel(consummation_electricite)

# %%
ce.head()
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INSTITUTIONNEL
# 4  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01     RÉSIDENTIEL
#
#    Total (kWh)
# 0     192890.0
# 1   15363686.0
# 2   68795794.7
# 3    5264076.0
# 4   51407699.0

# %%
ce.tail(3)
# Out:
#                REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS  \
# 430453  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430454  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430455  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
#
#                SECTEUR  Total (kWh)
# 430453      COMMERCIAL          NaN
# 430454  INSTITUTIONNEL          NaN
# 430455     RÉSIDENTIEL          NaN

# %%
ce.index
# Out:
# RangeIndex(start=0, stop=430456, step=1)

# %%
ce.columns
# Out:
# Index(['REGION_ADM_QC_TXT', 'MRC_TXT', 'NOM_MUNICIPALITE', 'ANNEE_MOIS',
#        'SECTEUR', 'Total (kWh)'],
#       dtype='object')

# %%
ce.to_numpy()
# Out:
# array([['Abitibi-Témiscamingue', nan, 'Rouyn-Noranda', '2016-01',
#         'AGRICOLE', 192890.0],
#        ['Abitibi-Témiscamingue', nan, 'Rouyn-Noranda', '2016-01',
#         'COMMERCIAL', 15363686.0],
#        ['Abitibi-Témiscamingue', nan, 'Rouyn-Noranda', '2016-01',
#         'INDUSTRIEL', 68795794.7],
#        ...,
#        ['Saguenay--Lac-Saint-Jean', nan, 'Mashteuiatsh', '2022-09',
#         'COMMERCIAL', nan],
#        ['Saguenay--Lac-Saint-Jean', nan, 'Mashteuiatsh', '2022-09',
#         'INSTITUTIONNEL', nan],
#        ['Saguenay--Lac-Saint-Jean', nan, 'Mashteuiatsh', '2022-09',
#         'RÉSIDENTIEL', nan]], dtype=object)

# %%
ce.describe()
# Out:
#         Total (kWh)
# count  1.309380e+05
# mean   4.392344e+06
# std    3.669849e+07
# min    2.700000e+02
# 25%    7.378075e+04
# 50%    2.851290e+05
# 75%    1.173424e+06
# max    2.079693e+09

# %%
ce.describe()
# Out:
#         Total (kWh)
# count  1.309380e+05
# mean   4.392344e+06
# std    3.669849e+07
# min    2.700000e+02
# 25%    7.378075e+04
# 50%    2.851290e+05
# 75%    1.173424e+06
# max    2.079693e+09

# %%
ce.head(5)
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INSTITUTIONNEL
# 4  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01     RÉSIDENTIEL
#
#    Total (kWh)
# 0     192890.0
# 1   15363686.0
# 2   68795794.7
# 3    5264076.0
# 4   51407699.0

# %%
ce.describe(include='object')
# Out:
#        REGION_ADM_QC_TXT              MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS  \
# count             430456               403354           430456     430456
# unique                17                   88             1128         81
# top           Montérégie  Vaudreuil-Soulanges    Saint-Isidore    2016-05
# freq               58634                 8667              810       5325
#
#             SECTEUR
# count        430456
# unique            5
# top     RÉSIDENTIEL
# freq          93224

# %%
ce.shape
# Out:
# (430456, 6)

# %%
ce.T
# Out:
#                                   0                      1       \
# REGION_ADM_QC_TXT  Abitibi-Témiscamingue  Abitibi-Témiscamingue
# MRC_TXT                              NaN                    NaN
# NOM_MUNICIPALITE           Rouyn-Noranda          Rouyn-Noranda
# ANNEE_MOIS                       2016-01                2016-01
# SECTEUR                         AGRICOLE             COMMERCIAL
# Total (kWh)                     192890.0             15363686.0
#
#                                   2                      3       \
# REGION_ADM_QC_TXT  Abitibi-Témiscamingue  Abitibi-Témiscamingue
# MRC_TXT                              NaN                    NaN
# NOM_MUNICIPALITE           Rouyn-Noranda          Rouyn-Noranda
# ANNEE_MOIS                       2016-01                2016-01
# SECTEUR                       INDUSTRIEL         INSTITUTIONNEL
# Total (kWh)                   68795794.7              5264076.0
#
# ...

# %%
ce.head()
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INSTITUTIONNEL
# 4  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01     RÉSIDENTIEL
#
#    Total (kWh)
# 0     192890.0
# 1   15363686.0
# 2   68795794.7
# 3    5264076.0
# 4   51407699.0

# %%
ce.sort_index(axis=1, ascending=False)
# Out:
#         Total (kWh)         SECTEUR         REGION_ADM_QC_TXT  \
# 0          192890.0        AGRICOLE     Abitibi-Témiscamingue
# 1        15363686.0      COMMERCIAL     Abitibi-Témiscamingue
# 2        68795794.7      INDUSTRIEL     Abitibi-Témiscamingue
# 3         5264076.0  INSTITUTIONNEL     Abitibi-Témiscamingue
# 4        51407699.0     RÉSIDENTIEL     Abitibi-Témiscamingue
# ...             ...             ...                       ...
# 430451          NaN     RÉSIDENTIEL  Saguenay--Lac-Saint-Jean
# 430452          NaN        AGRICOLE  Saguenay--Lac-Saint-Jean
# 430453          NaN      COMMERCIAL  Saguenay--Lac-Saint-Jean
# 430454          NaN  INSTITUTIONNEL  Saguenay--Lac-Saint-Jean
# 430455          NaN     RÉSIDENTIEL  Saguenay--Lac-Saint-Jean
#
#        NOM_MUNICIPALITE MRC_TXT ANNEE_MOIS
# 0         Rouyn-Noranda     NaN    2016-01
# 1         Rouyn-Noranda     NaN    2016-01
# 2         Rouyn-Noranda     NaN    2016-01
# 3         Rouyn-Noranda     NaN    2016-01
# ...

# %%
ce.sort_values(by="SECTEUR")
# Out:
#                REGION_ADM_QC_TXT             MRC_TXT         NOM_MUNICIPALITE  \
# 0          Abitibi-Témiscamingue                 NaN            Rouyn-Noranda
# 353951                Montérégie    Pierre-De Saurel               Saint-Aimé
# 137424      Chaudière-Appalaches  La Nouvelle-Beauce             Sainte-Marie
# 137419      Chaudière-Appalaches  La Nouvelle-Beauce             Sainte-Marie
# 353956                Montérégie    Pierre-De Saurel               Saint-Aimé
# ...                          ...                 ...                      ...
# 228154                    Estrie        Memphrémagog      Saint-Benoît-du-Lac
# 125522      Chaudière-Appalaches     Beauce-Sartigan  Saint-Honoré-de-Shenley
# 228152                    Estrie        Memphrémagog      Saint-Benoît-du-Lac
# 125527      Chaudière-Appalaches     Beauce-Sartigan  Saint-Honoré-de-Shenley
# 430455  Saguenay--Lac-Saint-Jean                 NaN             Mashteuiatsh
#
# ...

# %%
ce["ANNEE_MOIS"]
# Out:
# 0         2016-01
# 1         2016-01
# 2         2016-01
# 3         2016-01
# 4         2016-01
#            ...
# 430451    2022-08
# 430452    2022-09
# 430453    2022-09
# 430454    2022-09
# 430455    2022-09
# Name: ANNEE_MOIS, Length: 430456, dtype: object

# %%
ce[0:4]
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INSTITUTIONNEL
#
#    Total (kWh)
# 0     192890.0
# 1   15363686.0
# 2   68795794.7
# 3    5264076.0

# %%
ce.loc[:, ["NOM_MUNICIPALITE", "SECTEUR"]]
# Out:
#        NOM_MUNICIPALITE         SECTEUR
# 0         Rouyn-Noranda        AGRICOLE
# 1         Rouyn-Noranda      COMMERCIAL
# 2         Rouyn-Noranda      INDUSTRIEL
# 3         Rouyn-Noranda  INSTITUTIONNEL
# 4         Rouyn-Noranda     RÉSIDENTIEL
# ...                 ...             ...
# 430451     Mashteuiatsh     RÉSIDENTIEL
# 430452     Mashteuiatsh        AGRICOLE
# 430453     Mashteuiatsh      COMMERCIAL
# 430454     Mashteuiatsh  INSTITUTIONNEL
# 430455     Mashteuiatsh     RÉSIDENTIEL
#
# [430456 rows x 2 columns]

# %%
ce.loc[0:6,["NOM_MUNICIPALITE", "SECTEUR"] ]
# Out:
#   NOM_MUNICIPALITE         SECTEUR
# 0    Rouyn-Noranda        AGRICOLE
# 1    Rouyn-Noranda      COMMERCIAL
# 2    Rouyn-Noranda      INDUSTRIEL
# 3    Rouyn-Noranda  INSTITUTIONNEL
# 4    Rouyn-Noranda     RÉSIDENTIEL
# 5    Rouyn-Noranda        AGRICOLE
# 6    Rouyn-Noranda      COMMERCIAL

# %%
ce.loc[0, "SECTEUR"]
# Out:
# 'AGRICOLE'

# %%
ce.at[0, "SECTEUR"]
# Out:
# 'AGRICOLE'

# %%
ce.iloc[3]
# Out:
# REGION_ADM_QC_TXT    Abitibi-Témiscamingue
# MRC_TXT                                NaN
# NOM_MUNICIPALITE             Rouyn-Noranda
# ANNEE_MOIS                         2016-01
# SECTEUR                     INSTITUTIONNEL
# Total (kWh)                      5264076.0
# Name: 3, dtype: object

# %%
ce.iloc[3:5, 0:2]
# Out:
#        REGION_ADM_QC_TXT MRC_TXT
# 3  Abitibi-Témiscamingue     NaN
# 4  Abitibi-Témiscamingue     NaN

# %%
ce.iloc[[1, 2, 4], [0, 2]]
# Out:
#        REGION_ADM_QC_TXT NOM_MUNICIPALITE
# 1  Abitibi-Témiscamingue    Rouyn-Noranda
# 2  Abitibi-Témiscamingue    Rouyn-Noranda
# 4  Abitibi-Témiscamingue    Rouyn-Noranda

# %%
ce.iloc[1:3, :]
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS     SECTEUR  \
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INDUSTRIEL
#
#    Total (kWh)
# 1   15363686.0
# 2   68795794.7

# %%
ce.iloc[:, 1:3]
# Out:
#        MRC_TXT NOM_MUNICIPALITE
# 0          NaN    Rouyn-Noranda
# 1          NaN    Rouyn-Noranda
# 2          NaN    Rouyn-Noranda
# 3          NaN    Rouyn-Noranda
# 4          NaN    Rouyn-Noranda
# ...        ...              ...
# 430451     NaN     Mashteuiatsh
# 430452     NaN     Mashteuiatsh
# 430453     NaN     Mashteuiatsh
# 430454     NaN     Mashteuiatsh
# 430455     NaN     Mashteuiatsh
#
# [430456 rows x 2 columns]

# %%
ce.iloc[1, 1]
# Out:
# nan

# %%
ce.iat[1, 1]
# Out:
# nan

# %%
ce[ce["Total (kWh)"] > 800000]
# Out:
#                REGION_ADM_QC_TXT            MRC_TXT NOM_MUNICIPALITE  \
# 1          Abitibi-Témiscamingue                NaN    Rouyn-Noranda
# 2          Abitibi-Témiscamingue                NaN    Rouyn-Noranda
# 3          Abitibi-Témiscamingue                NaN    Rouyn-Noranda
# 4          Abitibi-Témiscamingue                NaN    Rouyn-Noranda
# 6          Abitibi-Témiscamingue                NaN    Rouyn-Noranda
# ...                          ...                ...              ...
# 426612  Saguenay--Lac-Saint-Jean  Maria-Chapdelaine        Normandin
# 426614  Saguenay--Lac-Saint-Jean  Maria-Chapdelaine        Normandin
# 426731  Saguenay--Lac-Saint-Jean  Maria-Chapdelaine        Normandin
# 426732  Saguenay--Lac-Saint-Jean  Maria-Chapdelaine        Normandin
# 426734  Saguenay--Lac-Saint-Jean  Maria-Chapdelaine        Normandin
#
#        ANNEE_MOIS         SECTEUR  Total (kWh)
# 1         2016-01      COMMERCIAL   15363686.0
# ...

# %%
ce2 = ce.copy()

# %%
import random

# %%
random_values = ["one", 'two', 'three', 'four', 'five']

# %%
ce2['ALEATORY'] = [random.choice(random_values) for _ in range(len(ce2))]

# %%
ce2
# Out:
#                REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS  \
# 0          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 1          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 2          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 3          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 4          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# ...                          ...     ...              ...        ...
# 430451  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-08
# 430452  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430453  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430454  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430455  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
#
#                SECTEUR  Total (kWh) ALEATORY
# 0             AGRICOLE     192890.0    three
# 1           COMMERCIAL   15363686.0    three
# ...

# %%
ce2[ce2['ALEATORY'].isin(["one", "four"])]
# Out:
#                REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS  \
# 2          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 3          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 9          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-02
# 13         Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-03
# 15         Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-04
# ...                          ...     ...              ...        ...
# 430443  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-06
# 430451  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-08
# 430452  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430453  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430454  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
#
#                SECTEUR  Total (kWh) ALEATORY
# 2           INDUSTRIEL   68795794.7      one
# 3       INSTITUTIONNEL    5264076.0     four
# ...

# %%
ce3 = ce2.reindex(index=ce2.index[0:4], columns=list(ce2.columns) + ['ALEATORY'])

# %%
ce3
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INSTITUTIONNEL
#
#    Total (kWh) ALEATORY ALEATORY
# 0     192890.0    three    three
# 1   15363686.0    three    three
# 2   68795794.7      one      one
# 3    5264076.0     four     four

# %%
ce3.loc[0:1,"ALEATORY"] = 1

# %%
ce3
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INSTITUTIONNEL
#
#    Total (kWh) ALEATORY ALEATORY
# 0     192890.0        1        1
# 1   15363686.0        1        1
# 2   68795794.7      one      one
# 3    5264076.0     four     four

# %%
ce3.dropna(how = "any")
# Out:
# Empty DataFrame
# Columns: [REGION_ADM_QC_TXT, MRC_TXT, NOM_MUNICIPALITE, ANNEE_MOIS, SECTEUR, Total (kWh), ALEATORY, ALEATORY]
# Index: []

# %%
ce3.fillna(value="empty")
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue   empty    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue   empty    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue   empty    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue   empty    Rouyn-Noranda    2016-01  INSTITUTIONNEL
#
#    Total (kWh) ALEATORY ALEATORY
# 0     192890.0        1        1
# 1   15363686.0        1        1
# 2   68795794.7      one      one
# 3    5264076.0     four     four

# %%
pd.isna(ce3)
# Out:
#    REGION_ADM_QC_TXT  MRC_TXT  NOM_MUNICIPALITE  ANNEE_MOIS  SECTEUR  \
# 0              False     True             False       False    False
# 1              False     True             False       False    False
# 2              False     True             False       False    False
# 3              False     True             False       False    False
#
#    Total (kWh)  ALEATORY  ALEATORY
# 0        False     False     False
# 1        False     False     False
# 2        False     False     False
# 3        False     False     False

# %% [markdown]
# Operations - Stats

# %%
ce.head()
# Out:
#        REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS         SECTEUR  \
# 0  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01        AGRICOLE
# 1  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      COMMERCIAL
# 2  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01      INDUSTRIEL
# 3  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01  INSTITUTIONNEL
# 4  Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01     RÉSIDENTIEL
#
#    Total (kWh)
# 0     192890.0
# 1   15363686.0
# 2   68795794.7
# 3    5264076.0
# 4   51407699.0

# %%
ce["Total (kWh)"].mean()
# Out:
# 4392343.7670336645

# %%
ce.agg({"Total (kWh)": lambda x: np.mean(x) * 5.6})
# Out:
#          Total (kWh)
# 0       1.080184e+06
# 1       8.603664e+07
# 2       3.852565e+08
# 3       2.947883e+07
# 4       2.878831e+08
# ...              ...
# 430451           NaN
# 430452           NaN
# 430453           NaN
# 430454           NaN
# 430455           NaN
#
# [430456 rows x 1 columns]

# %%
ce.transform({"Total (kWh)": lambda x: x * 101.2})
# Out:
#          Total (kWh)
# 0       1.952047e+07
# 1       1.554805e+09
# 2       6.962134e+09
# 3       5.327245e+08
# 4       5.202459e+09
# ...              ...
# 430451           NaN
# 430452           NaN
# 430453           NaN
# 430454           NaN
# 430455           NaN
#
# [430456 rows x 1 columns]

# %%
ce.value_counts()
# Out:
# REGION_ADM_QC_TXT         MRC_TXT            NOM_MUNICIPALITE           ANNEE_MOIS  SECTEUR         Total (kWh)
# Abitibi-Témiscamingue     Abitibi            La Morandière              2017-09     AGRICOLE        5698.0         1
# Laurentides               Deux-Montagnes     Deux-Montagnes             2016-09     INSTITUTIONNEL  953959.0       1
#                                                                         2017-01     INSTITUTIONNEL  1503932.0      1
#                                                                                     COMMERCIAL      1497336.0      1
#                                                                         2016-12     RÉSIDENTIEL     18848732.0     1
#                                                                                                                   ..
# Chaudière-Appalaches      L'Islet            Sainte-Perpétue            2020-07     AGRICOLE        41842.0        1
# ...

# %%
ce["SECTEUR"].str.lower()
# Out:
# 0               agricole
# 1             commercial
# 2             industriel
# 3         institutionnel
# 4            résidentiel
#                ...
# 430451       résidentiel
# 430452          agricole
# 430453        commercial
# 430454    institutionnel
# 430455       résidentiel
# Name: SECTEUR, Length: 430456, dtype: object

# %%
ce.groupby('SECTEUR')[["Total (kWh)"]].sum()
# Out:
#                  Total (kWh)
# SECTEUR
# AGRICOLE        6.205049e+09
# COMMERCIAL      1.436827e+11
# INDUSTRIEL      9.319440e+10
# INSTITUTIONNEL  3.804357e+10
# RÉSIDENTIEL     2.939990e+11

# %%
stacked = ce.stack()

# %%
stacked
# Out:
# 0       REGION_ADM_QC_TXT       Abitibi-Témiscamingue
#         NOM_MUNICIPALITE                Rouyn-Noranda
#         ANNEE_MOIS                            2016-01
#         SECTEUR                              AGRICOLE
#         Total (kWh)                          192890.0
#                                        ...
# 430454  SECTEUR                        INSTITUTIONNEL
# 430455  REGION_ADM_QC_TXT    Saguenay--Lac-Saint-Jean
#         NOM_MUNICIPALITE                 Mashteuiatsh
#         ANNEE_MOIS                            2022-09
#         SECTEUR                           RÉSIDENTIEL
# Length: 2256116, dtype: object

# %%
stacked.unstack()
# Out:
#                REGION_ADM_QC_TXT MRC_TXT NOM_MUNICIPALITE ANNEE_MOIS  \
# 0          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 1          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 2          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 3          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# 4          Abitibi-Témiscamingue     NaN    Rouyn-Noranda    2016-01
# ...                          ...     ...              ...        ...
# 430451  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-08
# 430452  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430453  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430454  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
# 430455  Saguenay--Lac-Saint-Jean     NaN     Mashteuiatsh    2022-09
#
#                SECTEUR Total (kWh)
# 0             AGRICOLE    192890.0
# 1           COMMERCIAL  15363686.0
# ...

# %%
pd.pivot_table(ce, values= "Total (kWh)", index=["SECTEUR"], columns=["ANNEE_MOIS"])
# Out:
# ANNEE_MOIS           2016-01       2016-02       2016-03       2016-04  \
# SECTEUR
# AGRICOLE        2.706572e+05  2.528056e+05  2.586837e+05  2.271791e+05
# COMMERCIAL      5.839038e+06  5.458336e+06  5.324846e+06  4.680668e+06
# INDUSTRIEL      6.201525e+06  5.971554e+06  6.404282e+06  6.093641e+06
# INSTITUTIONNEL  1.587884e+06  1.509015e+06  1.514965e+06  1.344661e+06
# RÉSIDENTIEL     1.618287e+07  1.443917e+07  1.269774e+07  9.755809e+06
#
# ANNEE_MOIS           2016-05       2016-06       2016-07       2016-08  \
# SECTEUR
# AGRICOLE        1.931920e+05  1.832886e+05  1.895280e+05  1.992904e+05
# COMMERCIAL      4.600248e+06  4.535381e+06  4.795255e+06  5.017081e+06
# INDUSTRIEL      6.485050e+06  5.885008e+06  5.787424e+06  6.343935e+06
# INSTITUTIONNEL  1.362882e+06  1.278404e+06  1.188759e+06  1.368371e+06
# RÉSIDENTIEL     6.909979e+06  5.974657e+06  6.190104e+06  6.494664e+06
#
# ANNEE_MOIS           2016-09       2016-10  ...       2021-12       2022-01  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(ce["SECTEUR"], ce["Total (kWh)"])
plt.xlabel("SECTEUR")
plt.ylabel("Total (kWh)")
plt.title("SECTEUR vs. Total (kWh)")
plt.show()
